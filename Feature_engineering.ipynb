# %%
import pandas as pd
import numpy as np
from pathlib import Path
from scipy.fft import rfft, rfftfreq
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("final_train_data.csv.gz")

# %%
print(list(df.columns.to_list()))
# Out:
# ['timestamp', 'Latitude (°)', 'Longitude (°)', 'Height (m)', 'Distance (cm)', 'Illuminance (lx)', 'amplitude', 'frequency', 'Horizontal Accuracy (m)', 'Vertical Accuracy (m)', 'Magnetic field x (µT)', 'Magnetic field y (µT)', 'Magnetic field z (µT)', 'Acceleration x (m/s^2)', 'Acceleration y (m/s^2)', 'Acceleration z (m/s^2)', 'Gyroscope x (rad/s)', 'Gyroscope y (rad/s)', 'Gyroscope z (rad/s)', 'Pressure (hPa)', 'Linear Acceleration x (m/s^2)', 'Linear Acceleration y (m/s^2)', 'Linear Acceleration z (m/s^2)', 'Common time (s)', 'Activity', 'Mood', 'Arousal ', 'Social engagement ', 'Noise Level', 'Concentration Level']

# %%
## creating additional columns summarizing columns 

# computing magnitude (Euclidean norm) of 3-D vector for acc, gyro & magn

sensor_axes = {
    "acc":  ['Acceleration x (m/s^2)',
             'Acceleration y (m/s^2)',
             'Acceleration z (m/s^2)'],
    "gyro": ['Gyroscope x (rad/s)',
             'Gyroscope y (rad/s)',
             'Gyroscope z (rad/s)'],
    "linacc": ['Linear Acceleration x (m/s^2)',
               'Linear Acceleration y (m/s^2)',
               'Linear Acceleration z (m/s^2)'],
    "mag":  ['Magnetic field x (µT)',
             'Magnetic field y (µT)',
             'Magnetic field z (µT)'],
}

for name, axes in sensor_axes.items():
    if all(col in df.columns for col in axes):
        df[f"{name}_mag"] = np.linalg.norm(df[axes].values, axis=1)
    else:
        missing = [c for c in axes if c not in df.columns]
        print(f"⚠️  Skipped {name}_mag — missing columns: {missing}")

print("now have:", [c for c in df.columns if c.endswith('_mag')])
# Out:
# now have: ['acc_mag', 'gyro_mag', 'linacc_mag', 'mag_mag']

# %%
df.to_csv("feature_engineered_final_train_data.csv", index=False)

# %%
print(df.columns.to_list())
# Out:
# ['timestamp', 'Latitude (°)', 'Longitude (°)', 'Height (m)', 'Distance (cm)', 'Illuminance (lx)', 'amplitude', 'frequency', 'Horizontal Accuracy (m)', 'Vertical Accuracy (m)', 'Magnetic field x (µT)', 'Magnetic field y (µT)', 'Magnetic field z (µT)', 'Acceleration x (m/s^2)', 'Acceleration y (m/s^2)', 'Acceleration z (m/s^2)', 'Gyroscope x (rad/s)', 'Gyroscope y (rad/s)', 'Gyroscope z (rad/s)', 'Pressure (hPa)', 'Linear Acceleration x (m/s^2)', 'Linear Acceleration y (m/s^2)', 'Linear Acceleration z (m/s^2)', 'Common time (s)', 'Activity', 'Mood', 'Arousal ', 'Social engagement ', 'Noise Level', 'Concentration Level', 'acc_mag', 'gyro_mag', 'linacc_mag', 'mag_mag']

# %%
df = pd.read_csv("feature_engineered_final_train_data.csv")
df["Common time (s)"] = pd.to_datetime(df["Common time (s)"])
df = df.sort_values("Common time (s)").reset_index(drop=True)

FS        = 407 # sampling rate (Hz) found during EDA
WIN_SEC   = 30  # look-back window before each EMA
GPS_BAD   = 50  # horiz-accuracy threshold (m)
MAG_SAT   = 300 # saturation μT
N_CLUST   = 3   # GPS k-means cluster count
win = pd.Timedelta(seconds=WIN_SEC)

# %%
## helper functions 
def haversine(lat1, lon1, lat2, lon2):
    R = 6_371_000  # metres
    lat1, lon1, lat2, lon2 = map(np.radians, (lat1, lon1, lat2, lon2))
    dlat, dlon = lat2 - lat1, lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1)*np.cos(lat2)*np.sin(dlon/2)**2
    return 2*R*np.arcsin(np.sqrt(a))

def dominant_freq(sig, fs):
    yf = np.abs(rfft(sig))
    xf = rfftfreq(len(sig), 1/fs)
    return xf[np.argmax(yf[1:])]     

def band_power(sig, fs, low, high):
    yf = np.abs(rfft(sig))
    xf = rfftfreq(len(sig), 1/fs)
    mask = (xf >= low) & (xf < high)
    return yf[mask].sum()

def orientation_angles(ax, ay, az):
    pitch = np.arctan2(-ax, np.sqrt(ay**2 + az**2))*180/np.pi
    roll  = np.arctan2( ay, az )*180/np.pi
    return pitch, roll

# %%
## computation of GPS clusters 
coords = df[["Latitude (°)", "Longitude (°)"]].dropna()
kmeans = KMeans(n_clusters=N_CLUST, random_state=42).fit(coords)
df["loc_cluster"] = kmeans.predict(df[["Latitude (°)", "Longitude (°)"]])

# %%
def extract_window_features(w):
    feat = {}

    # motion stats
    for col in ["acc_mag", "linacc_mag", "gyro_mag"]:
        feat[f"{col}_mean"] = w[col].mean()
        feat[f"{col}_std"]  = w[col].std()
        feat[f"{col}_q25"]  = w[col].quantile(.25)
        feat[f"{col}_q75"]  = w[col].quantile(.75)
        feat[f"{col}_cv"]   = w[col].std() / (w[col].mean() + 1e-9)

    jerk = np.abs(np.diff(w["acc_mag"])) * FS
    feat["jerk_mean"] = jerk.mean()

    # frequency
    feat["acc_dom_freq"] = dominant_freq(w["acc_mag"].values, FS)
    feat["acc_band0_3"]  = band_power(w["acc_mag"], FS, 0, 3)
    feat["acc_band3_10"] = band_power(w["acc_mag"], FS, 3, 10)

    # orientation
    pitch, _ = orientation_angles(
        w["Acceleration x (m/s^2)"],
        w["Acceleration y (m/s^2)"],
        w["Acceleration z (m/s^2)"],
    )
    pitch_arr = pitch.to_numpy()              
    feat["flat_ratio"]  = (np.abs(pitch_arr) < 10).mean()
    feat["orient_flips"] = np.sum(np.sign(pitch_arr[:-1]) != np.sign(pitch_arr[1:]))

    # environment
    feat["light_delta"]    = w["Illuminance (lx)"].iloc[-1] - w["Illuminance (lx)"].iloc[0]
    feat["pressure_delta"] = w["Pressure (hPa)"].iloc[-1]   - w["Pressure (hPa)"].iloc[0]
    feat["pocket_ratio"]   = (w["Distance (cm)"] == 5).mean()

    # GPS mobility
    lat, lon = w["Latitude (°)"].values, w["Longitude (°)"].values
    feat["dist_m"]     = haversine(lat[:-1], lon[:-1], lat[1:], lon[1:]).sum()
    feat["stop_ratio"] = ((w["Velocity (m/s)"].fillna(0) < 0.3).mean()
        if "Velocity (m/s)" in w.columns else np.nan)    
    feat["loc_cluster"]= w["loc_cluster"].mode().iat[0]

    # quality flags
    feat["gps_bad"]        = (w["Horizontal Accuracy (m)"] > GPS_BAD).any()
    feat["mag_saturation"] = (w["mag_mag"] > MAG_SAT).any()
    return feat

# %%
df.columns = df.columns.str.strip() 
print(df.columns.tolist())
# Out:
# ['timestamp', 'Latitude (°)', 'Longitude (°)', 'Height (m)', 'Distance (cm)', 'Illuminance (lx)', 'amplitude', 'frequency', 'Horizontal Accuracy (m)', 'Vertical Accuracy (m)', 'Magnetic field x (µT)', 'Magnetic field y (µT)', 'Magnetic field z (µT)', 'Acceleration x (m/s^2)', 'Acceleration y (m/s^2)', 'Acceleration z (m/s^2)', 'Gyroscope x (rad/s)', 'Gyroscope y (rad/s)', 'Gyroscope z (rad/s)', 'Pressure (hPa)', 'Linear Acceleration x (m/s^2)', 'Linear Acceleration y (m/s^2)', 'Linear Acceleration z (m/s^2)', 'Common time (s)', 'Activity', 'Mood', 'Arousal', 'Social engagement', 'Noise Level', 'Concentration Level', 'acc_mag', 'gyro_mag', 'linacc_mag', 'mag_mag', 'loc_cluster']

# %%
WIN_SAMP = int(WIN_SEC * FS)                   
rows_out = []

import time
rows = len(df)
start = time.time()
for i in range(len(df)):
    w = df.iloc[max(0, i-WIN_SAMP): i+1]
    if len(w) < 8:
        rows_out.append({})
        continue
    rows_out.append(extract_window_features(w))
    if i%2000 == 0:
        t = time.time()
        prc = (i/rows) * 100
        snc_start = ((t - start))
        estimate= (snc_start * (100 / prc)) - snc_start
        print(f"Progress: {(prc):.2f}% row {i}/{rows}. Time since start: {snc_start:.2f}s. Estimate: {estimate}s")

feat_df = pd.DataFrame(rows_out, index=df.index)
df_enriched = pd.concat([df, feat_df], axis=1)
df_enriched.to_csv("feature_engineered_final_train_data.csv",
                   index=False)
print("engineered features added:", df_enriched.shape)
# Out:
# Progress: 0.48% row 2000/416297. Time since start: 3.35s. Estimate: 694.278503350854s
# Progress: 0.96% row 4000/416297. Time since start: 7.30s. Estimate: 752.8069069563747s
# Progress: 1.44% row 6000/416297. Time since start: 12.23s. Estimate: 836.2298064215978s
# Progress: 1.92% row 8000/416297. Time since start: 17.85s. Estimate: 911.0021143861413s
# Progress: 2.40% row 10000/416297. Time since start: 24.36s. Estimate: 989.901026071s
# Progress: 2.88% row 12000/416297. Time since start: 31.66s. Estimate: 1066.6485262139638s
# Progress: 3.36% row 14000/416297. Time since start: 39.80s. Estimate: 1143.6078956104518s
# Progress: 3.84% row 16000/416297. Time since start: 48.16s. Estimate: 1204.8384270905406s
# Progress: 4.32% row 18000/416297. Time since start: 57.27s. Estimate: 1267.255151510596s
# Progress: 4.80% row 20000/416297. Time since start: 66.00s. Estimate: 1307.694582017827s
# Progress: 5.28% row 22000/416297. Time since start: 74.33s. Estimate: 1332.2241984861657s
# Progress: 5.77% row 24000/416297. Time since start: 82.72s. Estimate: 1352.0526211636563s
# Progress: 6.25% row 26000/416297. Time since start: 91.18s. Estimate: 1368.7862767879597s
# Progress: 6.73% row 28000/416297. Time since start: 99.55s. Estimate: 1380.5418056010606s
# Progress: 7.21% row 30000/416297. Time since start: 107.88s. Estimate: 1389.0968285108963s
# Progress: 7.69% row 32000/416297. Time since start: 116.07s. Estimate: 1393.8871898675413s
# 0              67.119613   0.003641  3.964895e-19                 0.169948
# 1              84.859563   2.712088  4.687500e+01                11.852118
# 2              84.795054   3.492394  4.687500e+01                11.809638
# 3              84.730545   4.362413  4.687500e+01                11.767157
# 4              84.666036   5.249622  4.687500e+01                11.724677
# ...                  ...        ...           ...                      ...
# 416292        142.381498   3.354277  2.812500e+02                14.901253
# 416293        142.381498   3.354277  2.812500e+02                14.901253
# 416294        142.381498   3.354277  2.812500e+02                14.901253
# 416295        142.381498   3.354277  2.812500e+02                14.901253
# 416296        142.381498   3.354277  2.812500e+02                14.901253
#
#         Vertical Accuracy (m)  ...  flat_ratio  orient_flips  light_delta  \
# 0                    0.024887  ...         NaN           NaN          NaN
# 1                    1.735556  ...         NaN           NaN          NaN
# 2                    1.729336  ...         NaN           NaN          NaN
# 3                    1.723115  ...         NaN           NaN          NaN
# 4                    1.716895  ...         NaN           NaN          NaN
# ...                       ...  ...         ...           ...          ...
# 416292               1.756246  ...    0.947261        2313.0   -71.618713
# 416293               1.756246  ...    0.947179        2313.0   -71.619861
# 416294               1.756246  ...    0.947097        2313.0   -71.621009
# 416295               1.756246  ...    0.947015        2313.0   -71.622158
# 416296               1.756246  ...    0.946933        2313.0   -71.623306
#
#         pressure_delta  pocket_ratio     dist_m  stop_ratio  loc_cluster  \
# 0                  NaN           NaN        NaN         NaN          NaN
# 1                  NaN           NaN        NaN         NaN          NaN
# 2                  NaN           NaN        NaN         NaN          NaN
# 3                  NaN           NaN        NaN         NaN          NaN
# 4                  NaN           NaN        NaN         NaN          NaN
# ...                ...           ...        ...         ...          ...
# 416292        0.013252           0.0  30.828607         NaN          0.0
# 416293        0.017296           0.0  30.828185         NaN          0.0
# 416294        0.010905           0.0  30.827764         NaN          0.0
# 416295        0.012132           0.0  30.827342         NaN          0.0
# 416296        0.013206           0.0  30.826921         NaN          0.0
#
#         gps_bad  mag_saturation
# 0           NaN             NaN
# 1           NaN             NaN
# 2           NaN             NaN
# 3           NaN             NaN
# 4           NaN             NaN
# ...         ...             ...
# 416292    False           False
# 416293    False           False
# 416294    False           False
# 416295    False           False
# 416296    False           False
#
# [416297 rows x 64 columns]

# %%
df.columns.to_list()
# Out:
# ['timestamp',
#  'Latitude (°)',
#  'Longitude (°)',
#  'Height (m)',
#  'Distance (cm)',
#  'Illuminance (lx)',
#  'amplitude',
#  'frequency',
#  'Horizontal Accuracy (m)',
#  'Vertical Accuracy (m)',
#  'Magnetic field x (µT)',
#  'Magnetic field y (µT)',
#  'Magnetic field z (µT)',
#  'Acceleration x (m/s^2)',
#  'Acceleration y (m/s^2)',
#  'Acceleration z (m/s^2)',
#  'Gyroscope x (rad/s)',
#  'Gyroscope y (rad/s)',
#  'Gyroscope z (rad/s)',
#  'Pressure (hPa)',
#  'Linear Acceleration x (m/s^2)',
#  'Linear Acceleration y (m/s^2)',
#  'Linear Acceleration z (m/s^2)',
#  'Common time (s)',
#  'Activity',
#  'Mood',
#  'Arousal',
#  'Social engagement',
#  'Noise Level',
#  'Concentration Level',
#  'acc_mag',
#  'gyro_mag',
#  'linacc_mag',
#  'mag_mag',
#  'loc_cluster']
