# %%
import pandas as pd
import numpy as np
from pathlib import Path
from scipy.fft import rfft, rfftfreq
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("final_data.csv.gz")

# %%
print(df.columns.to_list())
# Out:
# ['timestamp', 'Acceleration x (m/s^2)', 'Acceleration y (m/s^2)', 'Acceleration z (m/s^2)', 'amplitude', 'frequency', 'Gyroscope x (rad/s)', 'Gyroscope y (rad/s)', 'Gyroscope z (rad/s)', 'Illuminance (lx)', 'Linear Acceleration x (m/s^2)', 'Linear Acceleration y (m/s^2)', 'Linear Acceleration z (m/s^2)', 'Latitude (°)', 'Longitude (°)', 'Height (m)', 'Velocity (m/s)', 'Direction (°)', 'Horizontal Accuracy (m)', 'Vertical Accuracy (m)', 'Magnetic field x (µT)', 'Magnetic field y (µT)', 'Magnetic field z (µT)', 'Pressure (hPa)', 'Distance (cm)', 'Common time (s)', 'Activity', 'Mood', 'Arousal ', 'Social engagement ', 'Noise Level', 'Concentration Level']

# %%
## creating additional columns summarizing columns 

# computing magnitude (Euclidean norm) of 3-D vector for acc, gyro & magn

sensor_axes = {
    "acc":  ['Acceleration x (m/s^2)',
             'Acceleration y (m/s^2)',
             'Acceleration z (m/s^2)'],
    "gyro": ['Gyroscope x (rad/s)',
             'Gyroscope y (rad/s)',
             'Gyroscope z (rad/s)'],
    "linacc": ['Linear Acceleration x (m/s^2)',
               'Linear Acceleration y (m/s^2)',
               'Linear Acceleration z (m/s^2)'],
    "mag":  ['Magnetic field x (µT)',
             'Magnetic field y (µT)',
             'Magnetic field z (µT)'],
}

for name, axes in sensor_axes.items():
    if all(col in df.columns for col in axes):
        df[f"{name}_mag"] = np.linalg.norm(df[axes].values, axis=1)
    else:
        missing = [c for c in axes if c not in df.columns]
        print(f"⚠️  Skipped {name}_mag — missing columns: {missing}")

print("now have:", [c for c in df.columns if c.endswith('_mag')])

# remove the original acc, linacc & magfield from df?
# Out:
# now have: ['acc_mag', 'gyro_mag', 'linacc_mag', 'mag_mag']

# %%
df.to_csv("feature_engineered_final_data.csv", index=False)

# %%
df_sens = pd.read_csv("feature_engineered_final_data.csv")
df_sens["timestamp"] = pd.to_datetime(df_sens["timestamp"])

# 16-row questionnaire table
df_q    = pd.read_csv("feature_engineered_final_data.csv")
timestamps = pd.to_datetime(df_q["timestamp"])
df_q["timestamp"] = pd.to_datetime(df_q["timestamp"])

FS        = 407 # sampling rate (Hz) found during EDA
WIN_SEC   = 30  # look-back window before each EMA
GPS_BAD   = 50  # horiz-accuracy threshold (m)
MAG_SAT   = 300 # saturation μT
N_CLUST   = 3   # GPS k-means cluster count
win = pd.Timedelta(seconds=WIN_SEC)

# %%
anchor = pd.to_datetime(df_q["timestamp"]).min()     
sec = pd.to_numeric(df_sens["Common time (s)"], errors="coerce")

sec_offset = sec.iloc[0]       
aligned_sec = sec - sec_offset  

df_sens["timestamp"] = anchor + pd.to_timedelta(aligned_sec, unit="s")

# %%
## helper functions 

def haversine(lat1, lon1, lat2, lon2):
    R = 6_371_000  # metres
    lat1, lon1, lat2, lon2 = map(np.radians, (lat1, lon1, lat2, lon2))
    dlat, dlon = lat2 - lat1, lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1)*np.cos(lat2)*np.sin(dlon/2)**2
    return 2*R*np.arcsin(np.sqrt(a))

def dominant_freq(sig, fs):
    yf = np.abs(rfft(sig))
    xf = rfftfreq(len(sig), 1/fs)
    return xf[np.argmax(yf[1:])]     

def band_power(sig, fs, low, high):
    yf = np.abs(rfft(sig))
    xf = rfftfreq(len(sig), 1/fs)
    mask = (xf >= low) & (xf < high)
    return yf[mask].sum()

def orientation_angles(ax, ay, az):
    pitch = np.arctan2(-ax, np.sqrt(ay**2 + az**2))*180/np.pi
    roll  = np.arctan2( ay, az )*180/np.pi
    return pitch, roll

# %%
## computation of GPS clusters 

coords = df_sens[["Latitude (°)", "Longitude (°)"]].dropna()
kmeans = KMeans(n_clusters=N_CLUST, random_state=42).fit(coords)
df_sens["loc_cluster"] = kmeans.predict(df_sens[["Latitude (°)", "Longitude (°)"]])

# %%
def extract_window_features(w):
    feat = {}
        
    # motion stats
    for col in ["acc_mag", "linacc_mag", "gyro_mag"]:
        feat[f"{col}_mean"]  = w[col].mean()
        feat[f"{col}_std"]   = w[col].std()
        feat[f"{col}_q25"]   = w[col].quantile(.25)
        feat[f"{col}_q75"]   = w[col].quantile(.75)
        feat[f"{col}_cv"]    = w[col].std() / (w[col].mean() + 1e-9)

    # jerks
    jerk = np.abs(np.diff(w["acc_mag"])) * FS
    feat["jerk_mean"] = jerk.mean()

    # frequency fingerprints
    dom = dominant_freq(w["acc_mag"].values, FS)
    feat["acc_dom_freq"] = dom
    feat["acc_band0_3"]  = band_power(w["acc_mag"], FS, 0, 3)
    feat["acc_band3_10"] = band_power(w["acc_mag"], FS, 3, 10)

    # orientation metrics
    pitch, roll = orientation_angles(w["Acceleration x (m/s^2)"],
                                     w["Acceleration y (m/s^2)"],
                                     w["Acceleration z (m/s^2)"])
    flat_ratio = (np.abs(pitch) < 10).mean()
    feat["flat_ratio"] = flat_ratio
    flips = np.sum(np.sign(pitch[:-1]) != np.sign(pitch[1:]))
    feat["orient_flips"] = flips

    # environmental deltas
    feat["light_delta"]     = w["Illuminance (lx)"].iloc[-1] - w["Illuminance (lx)"].iloc[0]
    feat["pressure_delta"]  = w["Pressure (hPa)"].iloc[-1]   - w["Pressure (hPa)"].iloc[0]
    feat["pocket_ratio"]    = (w["Distance (cm)"] == 5).mean()

    # GPS mobility
    lat, lon = w["Latitude (°)"].values, w["Longitude (°)"].values
    dist = haversine(lat[:-1], lon[:-1], lat[1:], lon[1:]).sum()
    feat["dist_m"]       = dist
    feat["stop_ratio"]   = (w["Velocity (m/s)"].fillna(0) < 0.3).mean()
    feat["loc_cluster"]  = w["loc_cluster"].mode().iat[0]

    # quality flags
    feat["gps_bad"]       = (w["Horizontal Accuracy (m)"] > GPS_BAD).any()
    feat["mag_saturation"] = (w["mag_mag"] > MAG_SAT).any()

    return feat

# %%
df_q.columns    = df_q.columns.str.strip()      
df_sens.columns = df_sens.columns.str.strip()
print(df_q.columns.tolist())
# Out:
# ['timestamp', 'Acceleration x (m/s^2)', 'Acceleration y (m/s^2)', 'Acceleration z (m/s^2)', 'amplitude', 'frequency', 'Gyroscope x (rad/s)', 'Gyroscope y (rad/s)', 'Gyroscope z (rad/s)', 'Illuminance (lx)', 'Linear Acceleration x (m/s^2)', 'Linear Acceleration y (m/s^2)', 'Linear Acceleration z (m/s^2)', 'Latitude (°)', 'Longitude (°)', 'Height (m)', 'Velocity (m/s)', 'Direction (°)', 'Horizontal Accuracy (m)', 'Vertical Accuracy (m)', 'Magnetic field x (µT)', 'Magnetic field y (µT)', 'Magnetic field z (µT)', 'Pressure (hPa)', 'Distance (cm)', 'Common time (s)', 'Activity', 'Mood', 'Arousal', 'Social engagement', 'Noise Level', 'Concentration Level', 'acc_mag', 'gyro_mag', 'linacc_mag', 'mag_mag']

# %%
rows = []
win = pd.Timedelta(seconds=WIN_SEC)

for idx, q in df_q.iterrows():
    t_q = q["timestamp"]

    w = df_sens[
        (df_sens["timestamp"] >= t_q - win) &
        (df_sens["timestamp"] <  t_q)
    ]

    # ── Safety check ─────────────────────────────────────────────
    if w.empty:
        print(f"⚠️  window empty for EMA {idx} ({t_q}) — filling NaNs")
        feats = {k: np.nan for k in [
            "acc_mag_mean", "acc_mag_std", "gyro_mag_mean"]}
    else:
        feats = extract_window_features(w)
    # ─────────────────────────────────────────────────────────────

    # H. cross-modal
    feats["noisy_motion"]         = (q["Noise Level"] >= 3) * feats.get("acc_mag_mean", 0)
    feats["social_high_arousal"] = ((q["Social engagement"] >= 2) * q["Arousal"])
    # I. temporal deltas
    if idx > 0:
        for col in ["Mood", "Arousal", "Concentration Level"]:
            feats[f"Δ{col}"] = q[col] - df_q.loc[idx - 1, col]
    else:
        feats.update({"ΔMood": 0, "ΔArousal": 0, "ΔConcentration Level": 0})

    # K. circadian features
    hour = t_q.hour + t_q.minute / 60
    feats["tod_sin"] = np.sin(2 * np.pi * hour / 24)
    feats["tod_cos"] = np.cos(2 * np.pi * hour / 24)

    # raw EMA predictors + target
    feats.update({
        "Mood": q["Mood"],
        "Arousal": q["Arousal"],
        "Social engagement": q["Social engagement"],
        "Noise Level": q["Noise Level"],
        "Concentration Level": q["Concentration Level"],
        "timestamp": t_q,
    })

    rows.append(feats)

feature_df = (
    pd.DataFrame(rows)
      .set_index("timestamp")
      .sort_index()
)

print("Final feature table:", feature_df.shape)
feature_df.head()
# Out:
# ⚠️  window empty for EMA 0 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 1 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 2 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 3 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 4 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 5 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 6 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 7 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 8 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 9 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 10 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 11 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 12 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 13 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 14 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 15 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 16 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 17 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 18 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 19 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 20 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 21 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 22 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 23 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 24 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 25 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 26 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 27 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 28 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 29 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 30 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 31 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 32 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 33 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 34 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 35 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 36 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 37 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 38 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 39 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 40 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 41 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 42 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 43 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 44 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 45 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 46 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 47 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 48 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 49 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 50 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 51 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 52 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 53 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 54 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 55 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 56 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 57 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 58 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 59 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 60 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 61 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 62 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 63 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 64 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 65 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 66 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 67 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 68 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 69 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 70 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 71 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 72 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 73 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 74 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 75 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 76 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 77 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 78 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 79 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 80 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 81 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 82 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 83 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 84 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 85 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 86 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 87 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 88 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 89 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 90 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 91 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 92 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 93 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 94 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 95 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 96 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 97 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 98 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 99 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 100 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 101 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 102 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 103 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 104 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 105 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 106 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 107 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 108 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 109 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 110 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 111 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 112 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 113 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 114 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 115 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 116 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 117 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 118 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 119 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 120 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 121 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 122 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 123 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 124 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 125 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 126 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 127 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 128 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 129 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 130 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 131 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 132 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 133 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 134 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 135 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 136 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 137 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 138 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 139 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 140 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 141 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 142 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 143 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 144 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 145 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 146 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 147 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 148 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 149 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 150 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 151 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 152 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 153 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 154 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 155 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 156 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 157 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 158 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 159 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 160 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 161 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 162 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 163 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 164 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 165 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 166 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 167 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 168 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 169 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 170 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 171 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 172 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 173 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 174 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 175 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 176 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 177 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 178 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 179 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 180 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 181 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 182 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 183 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 184 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 185 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 186 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 187 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 188 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 189 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 190 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 191 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 192 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 193 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 194 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 195 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 196 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 197 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 198 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 199 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 200 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 201 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 202 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 203 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 204 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 205 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 206 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 207 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 208 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 209 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 210 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 211 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 212 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 213 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 214 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 215 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 216 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 217 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 218 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 219 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 220 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 221 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 222 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 223 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 224 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 225 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 226 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 227 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 228 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 229 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 230 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 231 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 232 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 233 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 234 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 235 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 236 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 237 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 238 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 239 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 240 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 241 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 242 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 243 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 244 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 245 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 246 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 247 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 248 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 249 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 250 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 251 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 252 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 253 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 254 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 255 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 256 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 257 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 258 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 259 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 260 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 261 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 262 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 263 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 264 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 265 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 266 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 267 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 268 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 269 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 270 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 271 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 272 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 273 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 274 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 275 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 276 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 277 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 278 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 279 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 280 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 281 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 282 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 283 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 284 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 285 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 286 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 287 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 288 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 289 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 290 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 291 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 292 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 293 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 294 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 295 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 296 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 297 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 298 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 299 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 300 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 301 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 302 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 303 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 304 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 305 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 306 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 307 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 308 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 309 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 310 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 311 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 312 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 313 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 314 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 315 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 316 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 317 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 318 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 319 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 320 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 321 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 322 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 323 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 324 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 325 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 326 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 327 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 328 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 329 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 330 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 331 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 332 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 333 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 334 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 335 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 336 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 337 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 338 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 339 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 340 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 341 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 342 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 343 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 344 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 345 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 346 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 347 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 348 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 349 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 350 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 351 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 352 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 353 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 354 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 355 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 356 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 357 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 358 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 359 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 360 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 361 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 362 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 363 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 364 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 365 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 366 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 367 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 368 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 369 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 370 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 371 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 372 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 373 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 374 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 375 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 376 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 377 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 378 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 379 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 380 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 381 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 382 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 383 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 384 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 385 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 386 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 387 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 388 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 389 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 390 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 391 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 392 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 393 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 394 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 395 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 396 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 397 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 398 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 399 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 400 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 401 (1970-01-01 00:00:00) — filling NaNs
# ⚠️  window empty for EMA 402 (1970-01-01 00:00:00) — filling NaNs
# /var/folders/lc/9q2gf4dn4snfnltmj87764500000gn/T/ipykernel_70409/1835825859.py:14: RuntimeWarning: Mean of empty slice.
#   feat["jerk_mean"] = jerk.mean()
# /Users/aylinogras/Desktop/MLQS/ML_for_Sensor_data-1/.venv/lib/python3.12/site-packages/numpy/_core/_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 18
#      15     feats = {k: np.nan for k in [
#      16         "acc_mag_mean", "acc_mag_std", "gyro_mag_mean"]}
#      17 else:
# ---> 18     feats = extract_window_features(w)
#      19 # ─────────────────────────────────────────────────────────────
#      20
#      21 # H. cross-modal
#      22 feats["noisy_motion"]         = (q["Noise Level"] >= 3) * feats.get("acc_mag_mean", 0)
#
# Cell In[28], line 17, in extract_window_features(w)
#      14 feat["jerk_mean"] = jerk.mean()
#      16 # frequency fingerprints
# ---> 17 dom = dominant_freq(w["acc_mag"].values, FS)
#      18 feat["acc_dom_freq"] = dom
#      19 feat["acc_band0_3"]  = band_power(w["acc_mag"], FS, 0, 3)
#
# Cell In[26], line 13, in dominant_freq(sig, fs)
#      11 yf = np.abs(rfft(sig))
#      12 xf = rfftfreq(len(sig), 1/fs)
# ---> 13 return xf[np.argmax(yf[1:])]
#
# File ~/Desktop/MLQS/ML_for_Sensor_data-1/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:1341, in argmax(a, axis, out, keepdims)
#    1252 """
#    1253 Returns the indices of the maximum values along an axis.
#    1254
#    (...)   1338 (2, 1, 4)
#    1339 """
#    1340 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1341 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File ~/Desktop/MLQS/ML_for_Sensor_data-1/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)     64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: attempt to get argmax of an empty sequence

# %%
df.to_csv("feature_engineered_final_data.csv", index=False)

# %%
existing = pd.read_csv("feature_engineered_final_data.csv")
existing["timestamp"] = pd.to_datetime(existing["timestamp"])
feature_df_reset = (feature_df.reset_index().rename(columns={"Timestamp": "timestamp"}))
updated = (existing.merge(feature_df_reset,on="timestamp",how="left"))
updated.to_csv("feature_engineered_final_data.csv", index=False)
print("Updated file written:", updated.shape)
# Out:
# Updated file written: (416297, 51)
